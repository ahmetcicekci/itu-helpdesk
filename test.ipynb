# %%
import pandas as pd

df = pd.read_json("itu_help_data.jsonl", lines=True)

# %%
df
# Out:
#                                                    url  \
# 0    https://yardim.itu.edu.tr/sss.aspx?id=99ba5a21...
# 1    https://yardim.itu.edu.tr/sss.aspx?id=a159cc17...
# 2    https://yardim.itu.edu.tr/sss.aspx?id=35dfad7a...
# 3    https://yardim.itu.edu.tr/sss.aspx?id=f595e8e1...
# 4    https://yardim.itu.edu.tr/sss.aspx?id=f942cce1...
# ..                                                 ...
# 697  https://yardim.itu.edu.tr/sss.aspx?id=1edd8b9a...
# 698  https://yardim.itu.edu.tr/sss.aspx?id=a9ae9116...
# 699  https://yardim.itu.edu.tr/sss.aspx?id=16879ef8...
# 700  https://yardim.itu.edu.tr/sss.aspx?id=4ead2bfc...
# 701  https://yardim.itu.edu.tr/sss.aspx?id=c8f198d4...
#
#                                                  title  \
# 0              ÖĞRENCI İŞLERI (OTOMASYON) ŞIFRESI/PINI
# 1    SISTEME GIRIŞTE YAŞANABILECEK SORUNLAR HAKKıNDA .
# 2    BIR BAŞKASıNıN KENDISINE AIT ÖĞRENCI BELGESI/T...
# 3    IP ÇAKıŞMASı NEDIR? IP ÇAKıŞMASı DURUMUNDA NE ...
# ...

# %%
print (df.loc[df.url == "https://yardim.itu.edu.tr/sss.aspx?id=edd8cb22-9d5c-4656-9274-fe7b4419e4b1"].content.iloc[0])
# Out:
# Fakülteden/enstitüden alınan görevlendirme
# Uçak (elektronik bilet) veya otobüs bileti
# Yurtdışı yolluk için pasaport kimlik ve mühür sayfalarının fotokopisi
# Varsa kongre katılım ücreti faturası veya ödeme dekontu
# Varsa konaklama faturası
# Varsa taksi fişleri, otobüs, tren biletleri
# Bu makale size yardımcı oldu mu?
# 1
# 2
# 3
# 4
# 5
